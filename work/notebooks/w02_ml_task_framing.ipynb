# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DivyankBaluni/ML-/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I chose the **Refresh / Content Opportunity Scoring** lane.
#
# This is primarily a **ranking / scoring** problem rather than a classification problem.
#
# The goal is not simply to predict whether a page is declining. Instead, the objective is to produce a ranked list of content pages so that editors can review the highest-priority pages first.
#
# Each page receives a priority score based on observable search and engagement signals, allowing reviewers to focus their effort where it is likely to have the greatest impact.

# %%
# No code required for this section.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The desired output is a **priority score** that ranks content pages according to how urgently they should be reviewed.
#
# As an initial proxy in the starter dataset, observable indicators such as declining trends, impressions, CTR, and other historical engagement signals can be used to estimate refresh priority.
#
# In later stages of the internship, this proxy can be refined using observed outcomes from the warehouse dataset rather than labels derived from fixed rules.

# %%
# No code required for this section.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Since this is a ranking task, the primary success metric is **Precision@K**.
#
# Precision@K measures how many of the highest-ranked pages actually represent worthwhile refresh opportunities.
#
# A higher Precision@K means that editors spend more time reviewing genuinely important pages and less time examining low-priority content.

# %%
# No code required for this section.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# The unit of analysis is **one content page**.
#
# Each row in the starter dataset represents one pseudonymized content item together with its search and engagement measurements collected over the trailing 90 days.
#
# This makes the content page the natural entity to score and rank for refresh opportunities.

# %%
import pandas as pd

df = pd.read_csv("ML_Internship/data/raw/content_refresh_anonymized.csv")

print("Shape:", df.shape)

df.head()
# Out:
# Shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule might recommend refreshing every page with low CTR or every page showing a declining trend.
#
# However, real content performance depends on many interacting signals, including impressions, search position, CTR, engagement, content age, and other observable metrics.
#
# ML can learn patterns across these interacting signals and produce a better priority ranking than a single manually designed rule.
#
# The output is intended to support editorial decision-making rather than replace human judgement.

# %%
df[[
    "content_id",
    "impressions_90d",
    "ctr",
    "avg_position",
    "trend_direction"
]].head()
# Out:
#              content_id  impressions_90d   ctr  avg_position trend_direction
# 0  content_304f48230142             3803  0.76          10.6            down
# 1  content_a1fb4e703a9e            15320  0.05          20.3            down
# 2  content_9aa793d4d895            12581  0.09          36.5            down
# 3  content_331d6c4de07b            11751  0.49           6.2          stable
# 4  content_d99b7a2d90ca            19140  0.13          44.0            down

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - ✔️ Every section above is filled — markdown thinking AND the code that backs it
# - ✔️ The notebook runs top to bottom with no errors (Runtime → Run all)
# - ✔️ No client names, URLs, or private queries anywhere
# - ✔️ My claims use careful words: observed, measured, directional, decision-support
# - ✔️ Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
